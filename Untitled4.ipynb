# %% [markdown]
# <a href="https://colab.research.google.com/github/IremOzbek/cats_dogs_classification/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Dec 22 13:55:54 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-e71e0c07-1cf4-4040-ad3b-57c86f3683b2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e71e0c07-1cf4-4040-ad3b-57c86f3683b2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d shaunthesheep/microsoft-catsvsdogs-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/shaunthesheep/microsoft-catsvsdogs-dataset
# License(s): other
# ...
#  93% 736M/788M [00:03<00:00, 177MB/s]
# 100% 788M/788M [00:09<00:00, 87.4MB/s]

# %%
# !unzip microsoft-catsvsdogs-dataset.zip
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: PetImages/Dog/550.jpg
#   inflating: PetImages/Dog/5500.jpg
#   inflating: PetImages/Dog/5501.jpg
#   inflating: PetImages/Dog/5502.jpg
#   inflating: PetImages/Dog/5503.jpg
#   inflating: PetImages/Dog/5504.jpg
#   inflating: PetImages/Dog/5505.jpg
#   inflating: PetImages/Dog/5506.jpg
#   inflating: PetImages/Dog/5507.jpg
#   inflating: PetImages/Dog/5508.jpg
#   inflating: PetImages/Dog/5509.jpg
#   inflating: PetImages/Dog/551.jpg
#   inflating: PetImages/Dog/5510.jpg
#   inflating: PetImages/Dog/5511.jpg
#   inflating: PetImages/Dog/5512.jpg
#   inflating: PetImages/Dog/5513.jpg
#   inflating: PetImages/Dog/5514.jpg
#   inflating: PetImages/Dog/5515.jpg
#   inflating: PetImages/Dog/5516.jpg
#   inflating: PetImages/Dog/5517.jpg
#   inflating: PetImages/Dog/5518.jpg
#   inflating: PetImages/Dog/5519.jpg
#   inflating: PetImages/Dog/552.jpg
#   inflating: PetImages/Dog/5520.jpg
#   inflating: PetImages/Dog/5521.jpg
# ...

# %%
# !ls
# Out:
#  kaggle.json			   'MSR-LA - 3467.docx'  'readme[1].txt'
#  microsoft-catsvsdogs-dataset.zip   PetImages		  sample_data

# %%
from PIL import Image
import os

def remove_corrupt_images(folder):
    for cls in ["Cat", "Dog"]:
        path = os.path.join(folder, cls)
        for img in os.listdir(path):
            try:
                Image.open(os.path.join(path, img)).verify()
            except:
                os.remove(os.path.join(path, img))

remove_corrupt_images("/content/PetImages")
# Out:
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))

# %%
import os
import shutil
import random

SOURCE_DIR = "/content/PetImages"
BASE_DIR = "/content/dataset"

TRAIN_DIR = os.path.join(BASE_DIR, "train")
VAL_DIR = os.path.join(BASE_DIR, "validation")

CATEGORIES = {"Cat": "cats", "Dog": "dogs"}
SPLIT_RATIO = 0.8  # %80 train, %20 validation

# Klasörleri oluştur
for split in [TRAIN_DIR, VAL_DIR]:
    for cls in CATEGORIES.values():
        os.makedirs(os.path.join(split, cls), exist_ok=True)

# Dosyaları ayır
for src_cls, target_cls in CATEGORIES.items():
    images = os.listdir(os.path.join(SOURCE_DIR, src_cls))
    random.shuffle(images)

    split_index = int(len(images) * SPLIT_RATIO)
    train_imgs = images[:split_index]
    val_imgs = images[split_index:]

    for img in train_imgs:
        shutil.copy(
            os.path.join(SOURCE_DIR, src_cls, img),
            os.path.join(TRAIN_DIR, target_cls, img)
        )

    for img in val_imgs:
        shutil.copy(
            os.path.join(SOURCE_DIR, src_cls, img),
            os.path.join(VAL_DIR, target_cls, img)
        )

print("Train / Validation ayrımı tamamlandı.")
# Out:
# Train / Validation ayrımı tamamlandı.

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 224
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

val_datagen = ImageDataGenerator(rescale=1./255)

train_data = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary"
)

val_data = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary"
)
# Out:
# Found 19998 images belonging to 2 classes.
# Found 5000 images belonging to 2 classes.

# %%
from tensorflow.keras import layers, models

base_model = tf.keras.applications.MobileNetV2(
    input_shape=(IMG_SIZE, IMG_SIZE, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False  # 🔒 Frozen
# Out:
# ...
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
model = models.Sequential([
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(128, activation="relu"),
    layers.Dropout(0.3),
    layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
history_frozen = model.fit(
    train_data,
    epochs=10,
    validation_data=val_data
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 493/625 ━━━━━━━━━━━━━━━━━━━━ 52s 396ms/step - accuracy: 0.9582 - loss: 0.1152
# /usr/local/lib/python3.12/dist-packages/PIL/TiffImagePlugin.py:950: UserWarning: Truncated File Read
#   warnings.warn(str(msg))
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 284s 428ms/step - accuracy: 0.9606 - loss: 0.1085 - val_accuracy: 0.9750 - val_loss: 0.0707
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 237s 379ms/step - accuracy: 0.9768 - loss: 0.0592 - val_accuracy: 0.9688 - val_loss: 0.0830
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 242s 387ms/step - accuracy: 0.9758 - loss: 0.0638 - val_accuracy: 0.9836 - val_loss: 0.0412
# ...

# %%
base_model.trainable = True

for layer in base_model.layers[:-30]:
    layer.trainable = False

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
history_finetune = model.fit(
    train_data,
    epochs=5,
    validation_data=val_data
)
# Out:
# Epoch 1/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 287s 421ms/step - accuracy: 0.9400 - loss: 0.1731 - val_accuracy: 0.9804 - val_loss: 0.0582
# Epoch 2/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 252s 403ms/step - accuracy: 0.9696 - loss: 0.0793 - val_accuracy: 0.9804 - val_loss: 0.0512
# Epoch 3/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 249s 399ms/step - accuracy: 0.9761 - loss: 0.0612 - val_accuracy: 0.9808 - val_loss: 0.0489
# Epoch 4/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 248s 396ms/step - accuracy: 0.9795 - loss: 0.0516 - val_accuracy: 0.9828 - val_loss: 0.0438
# Epoch 5/5
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 246s 394ms/step - accuracy: 0.9789 - loss: 0.0520 - val_accuracy: 0.9824 - val_loss: 0.0453

# %%
import matplotlib.pyplot as plt

def plot_history(history, title):
    plt.figure()
    plt.plot(history.history["accuracy"], label="Train Acc")
    plt.plot(history.history["val_accuracy"], label="Val Acc")
    plt.title(title)
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

plot_history(history_frozen, "Frozen MobileNetV2")
plot_history(history_finetune, "Fine-Tuned MobileNetV2")

# %%
import numpy as np
import matplotlib.pyplot as plt

# -----------------------------------
# 1. Validation setinden bir batch al
# -----------------------------------
images, labels = next(val_data)

# -----------------------------------
# 2. Model tahminleri
# -----------------------------------
preds = model.predict(images, verbose=0)

# Sigmoid çıktıyı sınıf etiketine çevir
pred_labels = (preds > 0.5).astype(int).reshape(-1)

# -----------------------------------
# 3. Yanlış tahmin edilen örnekler
# -----------------------------------
wrong_idx = np.where(pred_labels != labels)[0]

print(f"Yanlış sınıflandırılan örnek sayısı: {len(wrong_idx)}")

# -----------------------------------
# 4. Yanlış sınıflandırılan görselleri çiz
# -----------------------------------
num_show = min(8, len(wrong_idx))  # en fazla 8 tane göster

plt.figure(figsize=(14, 6))

for i in range(num_show):
    idx = wrong_idx[i]

    plt.subplot(2, 4, i + 1)
    plt.imshow(images[idx])
    plt.axis("off")

    true_label = "Dog" if labels[idx] == 1 else "Cat"
    pred_label = "Dog" if pred_labels[idx] == 1 else "Cat"
    confidence = preds[idx][0]

    plt.title(
        f"True: {true_label}\nPred: {pred_label}\nConf: {confidence:.2f}",
        fontsize=10,
        color="red"
    )

plt.suptitle("Misclassified Validation Samples", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Yanlış sınıflandırılan örnek sayısı: 1

# %%
import numpy as np
import matplotlib.pyplot as plt

all_images = []
all_labels = []
all_preds = []

# -----------------------------------
# 1. Tüm validation setini dolaş
# -----------------------------------
for i in range(len(val_data)):
    images, labels = val_data[i]
    preds = model.predict(images, verbose=0)

    all_images.extend(images)
    all_labels.extend(labels)
    all_preds.extend(preds)

all_images = np.array(all_images)
all_labels = np.array(all_labels)
all_preds = np.array(all_preds).reshape(-1)

pred_labels = (all_preds > 0.5).astype(int)

# -----------------------------------
# 2. Yanlış sınıflandırılan indeksler
# -----------------------------------
wrong_idx = np.where(pred_labels != all_labels)[0]

print(f"Toplam validation görüntüsü: {len(all_labels)}")
print(f"Yanlış sınıflandırılan görüntü sayısı: {len(wrong_idx)}")

# -----------------------------------
# 3. Yanlış örnekleri görselleştir
# -----------------------------------
num_show = min(8, len(wrong_idx))

plt.figure(figsize=(14, 6))

for i in range(num_show):
    idx = wrong_idx[i]

    plt.subplot(2, 4, i + 1)
    plt.imshow(all_images[idx])
    plt.axis("off")

    true_label = "Dog" if all_labels[idx] == 1 else "Cat"
    pred_label = "Dog" if pred_labels[idx] == 1 else "Cat"
    confidence = all_preds[idx]

    plt.title(
        f"True: {true_label}\nPred: {pred_label}\nConf: {confidence:.2f}",
        fontsize=10,
        color="red"
    )

plt.suptitle("Misclassified Samples from Entire Validation Set", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Toplam validation görüntüsü: 5000
# Yanlış sınıflandırılan görüntü sayısı: 88

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history_frozen.history["accuracy"])
plt.plot(history_frozen.history["val_accuracy"])
plt.plot(history_finetune.history["accuracy"])
plt.plot(history_finetune.history["val_accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Comparison: Frozen vs Fine-Tuned MobileNetV2")
plt.legend([
    "Frozen Train",
    "Frozen Validation",
    "Fine-Tuned Train",
    "Fine-Tuned Validation"
])
plt.show()

# %%
plt.figure()
plt.plot(history_frozen.history["loss"])
plt.plot(history_frozen.history["val_loss"])
plt.plot(history_finetune.history["loss"])
plt.plot(history_finetune.history["val_loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Comparison: Frozen vs Fine-Tuned MobileNetV2")
plt.legend([
    "Frozen Train",
    "Frozen Validation",
    "Fine-Tuned Train",
    "Fine-Tuned Validation"
])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc

# %%
import matplotlib.pyplot as plt

def plot_accuracy_loss(history, title):
    epochs = range(1, len(history.history["accuracy"]) + 1)

    # Accuracy
    plt.figure()
    plt.plot(epochs, history.history["accuracy"])
    plt.plot(epochs, history.history["val_accuracy"])
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.title(f"{title} - Accuracy")
    plt.legend(["Train Accuracy", "Validation Accuracy"])
    plt.show()

    # Loss
    plt.figure()
    plt.plot(epochs, history.history["loss"])
    plt.plot(epochs, history.history["val_loss"])
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(f"{title} - Loss")
    plt.legend(["Train Loss", "Validation Loss"])
    plt.show()

# %%
plot_accuracy_loss(history_frozen, "Frozen MobileNetV2")
plot_accuracy_loss(history_finetune, "Fine-Tuned MobileNetV2")

# %%
plt.figure()
plt.plot(history_frozen.history["val_accuracy"])
plt.plot(history_finetune.history["val_accuracy"])
plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy Comparison")
plt.legend([
    "Frozen MobileNetV2",
    "Fine-Tuned MobileNetV2"
])
plt.show()

# %%
plt.figure()
plt.plot(history_frozen.history["val_loss"])
plt.plot(history_finetune.history["val_loss"])
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Validation Loss Comparison")
plt.legend([
    "Frozen MobileNetV2",
    "Fine-Tuned MobileNetV2"
])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
import seaborn as sns
import pandas as pd

# %%
def plot_acc_loss(history, title):
    epochs = range(1, len(history.history['accuracy']) + 1)

    plt.figure(figsize=(12,4))

    plt.subplot(1,2,1)
    plt.plot(epochs, history.history['accuracy'], label='Train')
    plt.plot(epochs, history.history['val_accuracy'], label='Validation')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(epochs, history.history['loss'], label='Train')
    plt.plot(epochs, history.history['val_loss'], label='Validation')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_acc_loss(history_frozen, "Frozen MobileNetV2")
plot_acc_loss(history_finetune, "Fine-Tuned MobileNetV2")

# %%
y_true = []
y_pred = []
y_prob = []

for images, labels in val_data:
    preds = model.predict(images, verbose=0)
    y_true.extend(labels)
    y_prob.extend(preds)
    y_pred.extend((preds > 0.5).astype(int))

y_true = np.array(y_true)
y_pred = np.array(y_pred)
y_prob = np.array(y_prob)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-275145663.py in <cell line: 0>()
#       4
#       5 for images, labels in val_data:
# ----> 6     preds = model.predict(images, verbose=0)
#       7     y_true.extend(labels)
#       8     y_prob.extend(preds)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in predict(self, x, batch_size, verbose, steps, callbacks)
#     563             for step, iterator in epoch_iterator:
#     564                 callbacks.on_predict_batch_begin(step)
# ...

# %%
cm = confusion_matrix(y_true, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Cat', 'Dog'],
            yticklabels=['Cat', 'Dog'])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
fpr, tpr, _ = roc_curve(y_true, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f'AUC = {roc_auc:.3f}')
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
report = classification_report(
    y_true, y_pred,
    target_names=['Cat', 'Dog'],
    output_dict=True
)

df_report = pd.DataFrame(report).transpose()
df_report
# Out:
#               precision    recall  f1-score       support
# Cat            0.985016  0.979554  0.982277  17314.000000
# Dog            0.979681  0.985109  0.982387  17326.000000
# accuracy       0.982333  0.982333  0.982333      0.982333
# macro avg      0.982348  0.982332  0.982332  34640.000000
# weighted avg   0.982347  0.982333  0.982332  34640.000000
# WARNING: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
comparison_table = pd.DataFrame({
    "Model": ["Frozen MobileNetV2", "Fine-Tuned MobileNetV2"],
    "Best Val Accuracy": [
        max(history_frozen.history['val_accuracy']),
        max(history_finetune.history['val_accuracy'])
    ],
    "Final Val Loss": [
        history_frozen.history['val_loss'][-1],
        history_finetune.history['val_loss'][-1]
    ]
})

comparison_table
# Out:
#                     Model  Best Val Accuracy  Final Val Loss
# 0      Frozen MobileNetV2             0.9852        0.051318
# 1  Fine-Tuned MobileNetV2             0.9826        0.045988

# %%
images, labels = next(val_data)
preds = model.predict(images, verbose=0)

plt.figure(figsize=(12,6))
for i in range(8):
    plt.subplot(2,4,i+1)
    plt.imshow(images[i])
    plt.axis('off')
    true = 'Dog' if labels[i] == 1 else 'Cat'
    pred = 'Dog' if preds[i] > 0.5 else 'Cat'
    plt.title(f"T:{true} / P:{pred}")

plt.suptitle("Sample Predictions", fontsize=14)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Validation setinden bir batch al
images, labels = next(val_data)

# Model tahminleri
preds = model.predict(images, verbose=0)

# Binary tahminlere çevir (0/1)
pred_classes = (preds > 0.5).astype(int).reshape(-1)

# Yanlış tahmin edilen indeksleri bul
misclassified_idx = np.where(pred_classes != labels)[0]

print(f"Yanlış tahmin edilen örnek sayısı: {len(misclassified_idx)}")

# Eğer yanlış tahmin yoksa uyarı ver
if len(misclassified_idx) == 0:
    print("Bu batch içinde yanlış tahmin bulunamadı.")
else:
    # Gösterilecek maksimum görsel sayısı
    n_show = min(8, len(misclassified_idx))

    plt.figure(figsize=(12, 6))
    for i in range(n_show):
        idx = misclassified_idx[i]

        plt.subplot(2, 4, i + 1)
        plt.imshow(images[idx])
        plt.axis("off")

        true_label = "Dog" if labels[idx] == 1 else "Cat"
        pred_label = "Dog" if pred_classes[idx] == 1 else "Cat"
        confidence = preds[idx][0]

        plt.title(
            f"T: {true_label}\nP: {pred_label} ({confidence:.2f})",
            fontsize=10
        )

    plt.suptitle("Misclassified Samples (Error Analysis)", fontsize=14)
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1724285823.py in <cell line: 0>()
#       3
#       4 # Validation setinden bir batch al
# ----> 5 images, labels = next(val_data)
#       6
#       7 # Model tahminleri
#
# NameError: name 'val_data' is not defined

# %%
import matplotlib.pyplot as plt

studies = [
    "Adriyanto et al.",
    "Kausar (CNN)",
    "Jajodia & Garg",
    "Gupta (MobileNetV2)",
    "Proposed Method"
]

accuracies = [45, 89, 85, 98.0, 98.8]

plt.figure(figsize=(10,5))
plt.bar(studies, accuracies)
plt.ylabel("Accuracy (%)")
plt.title("Accuracy Comparison with Related Works")
plt.xticks(rotation=20)
plt.ylim(0,100)
plt.grid(axis="y", linestyle="--", alpha=0.6)
plt.show()
